# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('data.csv')

# %%
dataset
# Out:
#      Weather          Track Name          Artist  \
# 0        Fog                Cold       Novo Amor
# 1        Fog         Ylang Ylang             FKJ
# 2        Fog   I Wanted to Leave            SYML
# 3        Fog  Repeat Until Death       Novo Amor
# 4        Fog              Euphor       Novo Amor
# ...      ...                 ...             ...
# 6363   Clear   If You're Over Me   Years & Years
# 6364   Clear    We Can Do Better     Matt Simons
# 6365   Clear  Broken & Beautiful  Kelly Clarkson
# 6366   Clear         Wave of You        Surfaces
# 6367   Clear               HONEY       Derivakat
#
#                                   Album  \
# 0                          Woodgate, NY
# 1                        Ylang Ylang EP
# 2     I Wanted to Leave (Sitar Version)
# 3                            Birthplace
# 4                               Heiress
# ...                                 ...
# 6363                  If You're Over Me
# 6364                After The Landslide
# ...

# %%
print(dataset.describe())
# Out:
#         Popularity
# count  6368.000000
# mean     47.218907
# std      24.739335
# min       0.000000
# 25%      31.000000
# 50%      50.000000
# 75%      67.000000
# max      99.000000

# %%
# Find Outlier

plt.figure(figsize=(10,10))
dataset.boxplot()
plt.show()

# %%
# Percentile Batas Bawah

lowwer_limit = dataset['Popularity'].quantile(0)
lowwer_limit
# Out:
# 0.0

# %%
# Menampilkan data lowwer limit

dataset[dataset['Popularity'] > lowwer_limit]
# Out:
#      Weather          Track Name            Artist  \
# 1        Fog         Ylang Ylang               FKJ
# 2        Fog   I Wanted to Leave              SYML
# 3        Fog  Repeat Until Death         Novo Amor
# 4        Fog              Euphor         Novo Amor
# 5        Fog          EVERYTHING  The Black Skirts
# ...      ...                 ...               ...
# 6363   Clear   If You're Over Me     Years & Years
# 6364   Clear    We Can Do Better       Matt Simons
# 6365   Clear  Broken & Beautiful    Kelly Clarkson
# 6366   Clear         Wave of You          Surfaces
# 6367   Clear               HONEY         Derivakat
#
#                                   Album  \
# 1                        Ylang Ylang EP
# 2     I Wanted to Leave (Sitar Version)
# 3                            Birthplace
# 4                               Heiress
# 5                             TEAM BABY
# ...                                 ...
# 6363                  If You're Over Me
# ...

# %%
# Persentil batas atas

upper_limit = dataset['Popularity'].quantile(1)
upper_limit
# Out:
# 99.0

# %%
dataset[dataset['Popularity'] < upper_limit]
# Out:
#      Weather          Track Name          Artist  \
# 0        Fog                Cold       Novo Amor
# 1        Fog         Ylang Ylang             FKJ
# 2        Fog   I Wanted to Leave            SYML
# 3        Fog  Repeat Until Death       Novo Amor
# 4        Fog              Euphor       Novo Amor
# ...      ...                 ...             ...
# 6363   Clear   If You're Over Me   Years & Years
# 6364   Clear    We Can Do Better     Matt Simons
# 6365   Clear  Broken & Beautiful  Kelly Clarkson
# 6366   Clear         Wave of You        Surfaces
# 6367   Clear               HONEY       Derivakat
#
#                                   Album  \
# 0                          Woodgate, NY
# 1                        Ylang Ylang EP
# 2     I Wanted to Leave (Sitar Version)
# 3                            Birthplace
# 4                               Heiress
# ...                                 ...
# 6363                  If You're Over Me
# 6364                After The Landslide
# ...

# %%
# Remove Outlier

dataset_no_outlier = dataset[(dataset['Popularity'] > lowwer_limit) & (dataset['Popularity']< upper_limit)]

# %%
dataset_no_outlier
# Out:
#      Weather          Track Name            Artist  \
# 1        Fog         Ylang Ylang               FKJ
# 2        Fog   I Wanted to Leave              SYML
# 3        Fog  Repeat Until Death         Novo Amor
# 4        Fog              Euphor         Novo Amor
# 5        Fog          EVERYTHING  The Black Skirts
# ...      ...                 ...               ...
# 6363   Clear   If You're Over Me     Years & Years
# 6364   Clear    We Can Do Better       Matt Simons
# 6365   Clear  Broken & Beautiful    Kelly Clarkson
# 6366   Clear         Wave of You          Surfaces
# 6367   Clear               HONEY         Derivakat
#
#                                   Album  \
# 1                        Ylang Ylang EP
# 2     I Wanted to Leave (Sitar Version)
# 3                            Birthplace
# 4                               Heiress
# 5                             TEAM BABY
# ...                                 ...
# 6363                  If You're Over Me
# ...

# %%
plt.figure(figsize=(10,10))
dataset_no_outlier.boxplot()
plt.show()

# %%
# Cek jumlah outlier yang terhapus

dataset.shape[0] - dataset_no_outlier.shape[0]
# Out:
# 584
